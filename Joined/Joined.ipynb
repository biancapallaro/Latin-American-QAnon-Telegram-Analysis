# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 300)

# %%
mexico = pd.read_csv("mexico_joined.csv")
argentina = pd.read_csv("argentina_joined.csv")
venezuela = pd.read_csv("venezuela_joined.csv")
chile = pd.read_csv("chile_joined.csv")
uruguay = pd.read_csv("uruguay_joined.csv")
peru = pd.read_csv("peru_joined.csv")
colombia = pd.read_csv("colombia_joined.csv")

# %%
mexico['Country'] = 'Mexico'
argentina['Country'] = 'Argentina'
venezuela['Country'] = 'Venezuela'
chile['Country'] = 'Chile'
uruguay['Country'] = 'Uruguay'
peru['Country'] = 'Peru'
colombia['Country'] = 'Colombia'

# %%
frames = [mexico, argentina, venezuela, chile, uruguay, peru, colombia]

result = pd.concat(frames)

# %%
result
# Out:
#          index  day_date   Country
# 0   2021-01-11        53    Mexico
# 1   2021-01-12        49    Mexico
# 2   2021-01-10        48    Mexico
# 3   2020-05-16        43    Mexico
# 4   2021-01-17        43    Mexico
# ..         ...       ...       ...
# 95  2021-04-23         1  Colombia
# 96  2021-04-15         1  Colombia
# 97  2021-05-10         1  Colombia
# 98  2021-05-01         1  Colombia
# 99  2021-06-22         1  Colombia
#
# [1774 rows x 3 columns]

# %%
result.to_csv(r'/Users/biancapallaro/Desktop/joined_result.csv', index = False, header=True)

# %%
import altair as alt
alt.Chart(result).mark_area().encode(
    alt.X('index:T'),
    y = alt.Y("day_date:Q", stack=None),
    color = "Country",
    tooltip = ('index:T', 'day_date', 'Country')
).properties(
    width=850,
    height=300
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
alt.Chart(result).mark_area(opacity=0.3).encode(
    x="index:T",
    y=alt.Y("day_date:Q", stack=None),
    color="Country",
    tooltip = ('index:T', 'day_date', 'Country')
).properties(
    width=850,
    height=300
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
alt.Chart(result).mark_line().encode(
    x='index:T',
    y='day_date:Q',
    color='Country',
    tooltip = ('index:T', 'day_date', 'Country')
).properties(
    width=850,
    height=300
)
# Out:
# alt.Chart(...)

# %%
uruguay.day_date.sum()
# Out:
# 660
