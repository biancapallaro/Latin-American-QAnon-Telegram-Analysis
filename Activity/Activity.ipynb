# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 300)
# Out:
# /Users/biancapallaro/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
mexico = pd.read_csv("mexico_activity.csv")
argentina = pd.read_csv("argentina_activity.csv")
venezuela = pd.read_csv("venezuela_activity.csv")
chile = pd.read_csv("chile_activity.csv")
uruguay = pd.read_csv("uruguay_activity.csv")
peru = pd.read_csv("peru_activity.csv")
colombia = pd.read_csv("colombia_activity.csv")

# %%
mexico['Country'] = 'Mexico'
argentina['Country'] = 'Argentina'
venezuela['Country'] = 'Venezuela'
chile['Country'] = 'Chile'
uruguay['Country'] = 'Uruguay'
peru['Country'] = 'Peru'
colombia['Country'] = 'Colombia'

# %%
frames = [mexico, argentina, venezuela, chile, uruguay, peru, colombia]

result = pd.concat(frames)

# %%
result
# Out:
#           index  day_date   Country
# 0    2021-01-20      1617    Mexico
# 1    2021-01-11      1207    Mexico
# 2    2021-01-13       847    Mexico
# 3    2020-06-03       627    Mexico
# 4    2021-01-21       568    Mexico
# ..          ...       ...       ...
# 149  2021-02-14        21  Colombia
# 150  2021-02-21        20  Colombia
# 151  2021-03-03        17  Colombia
# 152  2021-02-20        14  Colombia
# 153  2021-02-13        12  Colombia
#
# [2079 rows x 3 columns]

# %%
result.to_csv(r'/Users/biancapallaro/Desktop/activity_result.csv', index = False, header=True)

# %%
import altair as alt
alt.Chart(result).mark_area().encode(
    alt.X('index:T'),
    y = alt.Y("day_date:Q", stack=None),
    color = "Country",
    tooltip = ('index:T', 'day_date', 'Country')
).properties(
    width=850,
    height=300
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
alt.Chart(result).mark_area(opacity=0.3).encode(
    x="index:T",
    y=alt.Y("day_date:Q", stack=None),
    color="Country",
    tooltip = ('index:T', 'day_date', 'Country')
).properties(
    width=850,
    height=300
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
alt.Chart(result).mark_line().encode(
    x='index:T',
    y='day_date:Q',
    color='Country',
    tooltip = ('index:T', 'day_date', 'Country')
).properties(
    width=850,
    height=300
)
# Out:
# alt.Chart(...)
